# %% [markdown]
# # Challenge: Real-Time Anomaly Detection

# %% [markdown]
# 1. **Understand the Existing Setup**: Ensure you are familiar with the feature processing script provided below.
# 2. **Write the Function `detect_anomaly()`**: The function call has already been placed in the correct position; now you need to write the function itself.
# 3. **Flag a Detected Anomaly**: Use a simple print function to output the anomaly value and the period when the anomaly occurred.

# %%
from quixstreams import Application
from datetime import datetime
import pandas as pd
import json


def parse_period(period_str):
    # Streamlined date formats for known input formats
    date_formats = ['%Y-%m-%d %H:%M:%S', '%Y-%m-%dT%H:%M:%S', '%Y-%m-%dT%H', '%Y-%m-%d %H:%M']
    for date_format in date_formats:
        try:
            return datetime.strptime(period_str, date_format)
        except ValueError:
            continue
    print(f"Failed to parse date: {period_str}")
    return None

def calculate_lags(window):
    # Convert window to a DataFrame
    df = pd.DataFrame({'value': window})
    
    features = {
        'lag_1': float(df['value'].shift(1).iloc[-1]) if len(df) > 1 else None,
        'lag_2': float(df['value'].shift(2).iloc[-1]) if len(df) > 2 else None,
        'lag_6': float(df['value'].shift(6).iloc[-1]) if len(df) > 6 else None,
        'lag_12': float(df['value'].shift(12).iloc[-1]) if len(df) > 12 else None,
        'lag_24': float(df['value'].shift(24).iloc[-1]) if len(df) > 24 else None,
        'rolling_mean_7': float(df['value'].rolling(window=7).mean().iloc[-1]) if len(df) >= 7 else None,
        'rolling_std_7': float(df['value'].rolling(window=7).std().iloc[-1]) if len(df) >= 7 else None,
    }
    
    return features

def detect_anomaly(value, window, threshold=2):
    if len(window) < 7:
        return False  # Not enough data to calculate rolling statistics
    
    df = pd.DataFrame({'value': window})
    rolling_mean = df['value'].rolling(window=7).mean().iloc[-1]
    rolling_std = df['value'].rolling(window=7).std().iloc[-1]
    
    if abs(value - rolling_mean) > threshold * rolling_std:
        return True
    return False

def feature_pipeline_online(value, state, producer, feature_store_topic):
    period_dt = parse_period(value['Period'])
    
    if period_dt is None:
        print("Error parsing the period date.")
        return
    
    feature_record_id = period_dt.strftime('%Y-%m-%d %H')
    
    if value['Type'] == 'energy':
        window = state.get('energy_window', [])
        window.append(value['Value'])        
        if len(window) > 25:
            window.pop(0)
        
        state.set('energy_window', window)
        
        if detect_anomaly(value['Value'], window):
            print(f"Anomaly detected: {value['Value']} at {period_dt}")

        features = calculate_lags(window)
        features.update({'hour': period_dt.hour,
            'day_of_week': period_dt.weekday(),
            'month': period_dt.month})
        
        message = {
            "id": feature_record_id,
            **features
        }

        producer.produce(topic=feature_store_topic.name, key=feature_record_id, value=json.dumps(message))
    
    elif value['Type'] == 'temperature':
        message = {
            'id': feature_record_id,
            'temperature_forecast': value['Value']
        }
        producer.produce(topic=feature_store_topic.name, key=feature_record_id, value=json.dumps(message))

app = Application(broker_address='localhost:9092', consumer_group='example')

# Define a topic for real-time feature storage with JSON serialization
feature_store_topic = app.topic(name='feature_store', value_serializer='json')

# Combined data topic setup
incoming_data_topic = app.topic(name='incoming_data', value_deserializer='json')

# Producer for sending feature data
with app.get_producer() as producer:
    # Simulate or integrate data handling and processing
    data_df = app.dataframe(topic=incoming_data_topic).update(
        lambda value, state: feature_pipeline_online(value, state, producer, feature_store_topic), 
        stateful=True
    )
    app.run(data_df)
# Out:
# ---------------------------------------------------------------------------
# KafkaException                            Traceback (most recent call last)
# Cell In[1], line 88
#      85 app = Application(broker_address='localhost:9092', consumer_group='example')
#      87 # Define a topic for real-time feature storage with JSON serialization
# ---> 88 feature_store_topic = app.topic(name='feature_store', value_serializer='json')
#      90 # Combined data topic setup
#      91 incoming_data_topic = app.topic(name='incoming_data', value_deserializer='json')
#
# File /workspaces/LL_real-time-data-forecasting-with-ai-and-python-4565024/ai_tsf/lib/python3.10/site-packages/quixstreams/app.py:500, in Application.topic(self, name, value_deserializer, key_deserializer, value_serializer, key_serializer, config, timestamp_extractor)
#     430 def topic(
#     431     self,
#     432     name: str,
#    (...)
#     438     timestamp_extractor: Optional[TimestampExtractor] = None,
#     439 ) -> Topic:
#     440     """
#     441     Create a topic definition.
#     442
#    (...)
#     498     :return: `Topic` object
#     499     """
# --> 500     return self._topic_manager.topic(
#     501         name=name,
#     502         key_serializer=key_serializer,
#     503         value_serializer=value_serializer,
#     504         key_deserializer=key_deserializer,
#     505         value_deserializer=value_deserializer,
#     506         create_config=config,
#     507         timestamp_extractor=timestamp_extractor,
#     508     )
#
# File /workspaces/LL_real-time-data-forecasting-with-ai-and-python-4565024/ai_tsf/lib/python3.10/site-packages/quixstreams/models/topics/manager.py:179, in TopicManager.topic(self, name, value_deserializer, key_deserializer, value_serializer, key_serializer, create_config, timestamp_extractor)
#     163     create_config = TopicConfig(
#     164         num_partitions=self.default_num_partitions,
#     165         replication_factor=self.default_replication_factor,
#     166         extra_config=self.default_extra_config,
#     167     )
#     169 topic = Topic(
#     170     name=name,
#     171     value_serializer=value_serializer,
#    (...)
#     177     topic_type=TopicType.REGULAR,
#     178 )
# --> 179 broker_topic = self._get_or_create_broker_topic(topic)
#     180 topic = self._configure_topic(topic, broker_topic)
#     181 self._regular_topics[topic.name] = topic
#
# File /workspaces/LL_real-time-data-forecasting-with-ai-and-python-4565024/ai_tsf/lib/python3.10/site-packages/quixstreams/models/topics/manager.py:388, in TopicManager._get_or_create_broker_topic(self, topic)
#     383 """
#     384 Validates the original topic name and returns the Topic from the broker
#     385 either by fetching it or creating it if it doesn't exist.
#     386 """
#     387 try:
# --> 388     return self._fetch_topic(topic=topic)
#     389 except TopicNotFoundError:
#     390     if not self._auto_create_topics:
#
# File /workspaces/LL_real-time-data-forecasting-with-ai-and-python-4565024/ai_tsf/lib/python3.10/site-packages/quixstreams/models/topics/manager.py:371, in TopicManager._fetch_topic(self, topic)
#     369 def _fetch_topic(self, topic: Topic) -> Topic:
#     370     topic_name = topic.name
# --> 371     actual_configs = self._admin.inspect_topics(
#     372         [topic_name],
#     373         timeout=self._timeout,
#     374     )
#     375     topic_config = actual_configs[topic_name]
#     376     if topic_config is None:
#
# File /workspaces/LL_real-time-data-forecasting-with-ai-and-python-4565024/ai_tsf/lib/python3.10/site-packages/quixstreams/models/topics/admin.py:98, in TopicAdmin.inspect_topics(self, topic_names, timeout)
#      86 """
#      87 A simplified way of getting the topic configurations of the provided topics
#      88 from the cluster (if they exist).
#    (...)
#      95 :return: a dict with topic names and their respective `TopicConfig`
#      96 """
#      97 futures_dict = {}
# ---> 98 cluster_topics = self.list_topics(timeout=timeout)
#      99 if existing_topics := [
#     100     topic for topic in topic_names if topic in cluster_topics
#     101 ]:
#     102     futures_dict = self.admin_client.describe_configs(
#     103         [confluent_topic_config(topic) for topic in existing_topics],
#     104         request_timeout=timeout,
#     105     )
#
# File /workspaces/LL_real-time-data-forecasting-with-ai-and-python-4565024/ai_tsf/lib/python3.10/site-packages/quixstreams/models/topics/admin.py:79, in TopicAdmin.list_topics(self, timeout)
#      71 """
#      72 Get a list of topics and their metadata from a Kafka cluster
#      73
#    (...)
#      76 :return: a dict of topic names and their metadata objects
#      77 """
#      78 # TODO: allow filtering based on a prefix ignore list?
# ---> 79 return self.admin_client.list_topics(timeout=timeout).topics
#
# File /workspaces/LL_real-time-data-forecasting-with-ai-and-python-4565024/ai_tsf/lib/python3.10/site-packages/confluent_kafka/admin/__init__.py:639, in AdminClient.list_topics(self, *args, **kwargs)
#     637 def list_topics(self, *args, **kwargs):
# --> 639     return super(AdminClient, self).list_topics(*args, **kwargs)
#
# KafkaException: KafkaError{code=_TRANSPORT,val=-195,str="Failed to get metadata: Local: Broker transport failure"}
